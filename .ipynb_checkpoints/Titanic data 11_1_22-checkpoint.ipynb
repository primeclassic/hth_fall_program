# %%
import pandas
import seaborn
import matplotlib.pyplot as plt

''' 
The best way to complete this activity is to copy the code in this file into a jupyter notebook file you create. This will also you to see your visualizations easier. Once you have finished creating your visuals copy your code back into this file and submit it to Replit. Don't forget to also upload your new code to Github! 
'''
# Call our titanic csv
titanic_data = pandas.read_csv("Basic-Pandas-Manipulation/titanic.csv")
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Step 1: Create a heatmap showing the correlation between the following features: survival, pclass, sex, age, and fare 
titanic_features = titanic_data[["Survived","Pclass","Age","Fare"]]

corr_heatmap = seaborn.heatmap(titanic_features.corr(), annot = True, cmap = 'mako')
plt.show()

# %%
# Step 2: Create a bar graph that illustrates how many passengers fell into each of these age ranges: 0 - 16, 17 - 25, 26 -40, 41 - 59, 60 or older
# titanic_data[(titanic_data['Age'] <= 16) & (titanic_data['Age'] >= 0)]
# titanic_data[(titanic_data['Age'] >= 17) & (titanic_data['Age'] <= 25)]
# titanic_data[(titanic_data['Age'] >= 26) & (titanic_data['Age'] <= 40)]
# titanic_data[( titanic_data['Age'] >= 41) & ( titanic_data['Age'] <= 59)]
#titanic_data[titanic_data['Age'] >= 60]
# This plot has both graphs on the axis you outlined in your code, 
# I used the ci = None parameter to remove the confidence intervals to
# make the combined plot easier to read (optional)
age_group = { 
"groups" : ['16 or younger','17-25','26-40','41-60','61 and older'],
"count":[
    len(titanic_data[(titanic_data['Age'] <= 16) & (titanic_data['Age'] >= 0)]),
    len(titanic_data[(titanic_data['Age'] >= 17) & (titanic_data['Age'] <= 25)]),
    len(titanic_data[(titanic_data['Age'] >= 26) & (titanic_data['Age'] <= 40)]),
    len(titanic_data[( titanic_data['Age'] >= 41) & ( titanic_data['Age'] <= 59)]),
    len(titanic_data[titanic_data['Age'] >= 60])]
         }
vis_df = pandas.DataFrame(age_group)
seaborn.barplot(data = vis_df, x = "groups", y = "count")
# age_group_chart =
# Out:
# <AxesSubplot: xlabel='groups', ylabel='count'>

# %%
# Step 3: Create a line graph showing the average survival percentage of each of the previous age groups
# age_group = { 
# "groups" : ['16 or younger','17-25','26-40','41-60','61 and older'],
# "survival percent":[
#     len(titanic_data[(titanic_data['Age'] <= 16) & (titanic_data['Age'] >= 0)])/titanic_data.Survived.count(),
#     len(titanic_data[(titanic_data['Age'] >= 17) & (titanic_data['Age'] <= 25)])/titanic_data.Survived.count(),
#     len(titanic_data[(titanic_data['Age'] >= 26) & (titanic_data['Age'] <= 40)])/titanic_data.Survived.count(),
#     len(titanic_data[( titanic_data['Age'] >= 41) & ( titanic_data['Age'] <= 59)])/titanic_data.Survived.count(),
#     len(titanic_data[titanic_data['Age'] >= 60])/titanic_data.Survived.count()]
#          }
# # survival_age_pers = 
# vis_df = pandas.DataFrame(age_group)
# seaborn.barplot(data = vis_df, x = "groups", y = "survival percent")
age_group = { 
"groups" : ['16 or younger','17-25','26-40','41-60','61 and older'],
"count":[
    len(titanic_data[(titanic_data['Age'] <= 16) & (titanic_data['Age'] >= 0)]),
    len(titanic_data[(titanic_data['Age'] >= 17) & (titanic_data['Age'] <= 25)]),
    len(titanic_data[(titanic_data['Age'] >= 26) & (titanic_data['Age'] <= 40)]),
    len(titanic_data[( titanic_data['Age'] >= 41) & ( titanic_data['Age'] <= 59)]),
    len(titanic_data[titanic_data['Age'] >= 60])],
"survived":[
    len(titanic_data[(titanic_data['Age'] <= 16) & (titanic_data['Age'] >= 0) & (titanic_data['Survived'] == 1)]),
    len(titanic_data[(titanic_data['Age'] >= 17) & (titanic_data['Age'] <= 25) & (titanic_data['Survived'] == 1)]),
    len(titanic_data[(titanic_data['Age'] >= 26) & (titanic_data['Age'] <= 40) & (titanic_data['Survived'] == 1)]),
    len(titanic_data[( titanic_data['Age'] >= 41) & ( titanic_data['Age'] <= 59)& (titanic_data['Survived'] ==1)]),
    len(titanic_data[(titanic_data['Age'] >= 60) & (titanic_data['Survived'] == 1)])]
    }
vis_df = pandas.DataFrame(age_group)
percent = vis_df['survived'] / vis_df['count']
# percent, vis_df
seaborn.lineplot(data = vis_df, x = "groups", y = percent)
# Out:
# <AxesSubplot: xlabel='groups'>

# %%
titanic_data[(titanic_data['Age'] >= 60) & (titanic_data['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 570          571         1       2
# 587          588         1       1
# 630          631         1       1
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# 570                                Harris, Mr. George    male  62.0      0
# 587                  Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 630              Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#      Parch       Ticket     Fare Cabin Embarked
# ...

# %%
# Step 4: Create a pie chart that shows the percentage of survivors that were male and the percentage of survivors that were female
survivors = 

# Step 5: Create a histogram that shows the distribution of passengers between the three embarking locations: C (Cherbourg), Q (Queenstown), S (Southampton)
titanic_description =

# %%
titanic_data
# vis_df[]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Step 4: Create a pie chart that shows the percentage of survivors that were male and the percentage of survivors that were female
# survivors = 
malePercent = (titanic_data['Sex'] == "male").mean()
femalePercent = 1 - malePercent
maleSurvivors = ((titanic_data['Sex'] == "male") & (titanic_data['Survived'] == 1)).mean()
femaleSurvivors = ((titanic_data['Sex'] == "female") & (titanic_data['Survived'] == 1)).mean()
deadPeople = (titanic_data['Survived'] == 0).mean()
data=[maleSurvivors,femaleSurvivors,deadPeople]
key=['maleSurvor','femaleSurvior','dead']
plt.pie(data,labels = key,autopct='%.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Step 5: Create a histogram that shows the distribution of passengers between the three embarking locations: C (Cherbourg), Q (Queenstown), S (Southampton)
Embarked_Location = {
"groups" : ['Cherbourg','Queenstown','Southampton'],
"count" : [
    (titanic_data['Embarked'] == "C").sum(),
    (titanic_data['Embarked'] == "Q").sum(),
    (titanic_data['Embarked'] == "S").sum()
]
}
seaborn.histplot(data = Embarked_Location,x = "groups", y = "count")
# pandas.DataFrame(Embarked_Location).plot.hist(by='groups')
# pandas.titanic_description.hist
# Out:
# <AxesSubplot: xlabel='groups', ylabel='count'>
